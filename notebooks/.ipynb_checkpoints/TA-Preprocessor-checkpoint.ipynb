# %%
# Import the funtime and funpicker library

# %%
# Import the query
from funtime import Store, Converter
from funpicker import Query
# Out:
# /home/kevin/.local/share/virtualenvs/predecessor-IKHhjMIk/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /home/kevin/.local/share/virtualenvs/predecessor-IKHhjMIk/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
import pandas as pd
import numpy as np

# %%
import talib as ta

# %%
store = Store().create_lib("ticker.Price").get_store()

# %%
tickstore = store["ticker.Price"]

# %%
def df_set_time(price_frame):
    if not isinstance(price_frame, pd.DataFrame):
        raise TypeError("Should be a dataframe")
    time_series = pd.to_datetime(price_frame['time'], unit='s')
    price_frame.drop('time', axis=1)
    price_frame.set_index(time_series, inplace=True)
    return price_frame

# %%
hourly_eth = Query().set_crypto("ETH").set_fiat("USD").set_exchange("bittrex").set_period("hour").set_limit(500).get()

# %%
hourly_eth
# Out:
# [{'time': 1533290400,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533294000,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533297600,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533301200,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533304800,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533308400,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533312000,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533315600,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533319200,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533322800,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533326400,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533330000,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533333600,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533337200,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533340800,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533344400,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533348000,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533351600,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533355200,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533358800,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533362400,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533366000,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533369600,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533373200,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533376800,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533380400,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533384000,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533387600,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533391200,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533394800,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533398400,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533402000,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533405600,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533409200,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533412800,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533416400,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533420000,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533423600,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533427200,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533430800,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533434400,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533438000,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533441600,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533445200,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533448800,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533452400,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533456000,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533459600,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533463200,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533466800,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533470400,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533474000,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533477600,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533481200,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533484800,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533488400,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533492000,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533495600,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533499200,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533502800,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533506400,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533510000,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533513600,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533517200,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533520800,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533524400,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533528000,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533531600,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533535200,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533538800,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533542400,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533546000,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533549600,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533553200,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533556800,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533560400,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533564000,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533567600,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533571200,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533574800,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533578400,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533582000,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533585600,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533589200,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533592800,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533596400,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533600000,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533603600,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533607200,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533610800,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533614400,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533618000,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533621600,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533625200,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533628800,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533632400,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533636000,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533639600,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533643200,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533646800,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533650400,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533654000,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533657600,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533661200,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533664800,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533668400,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533672000,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533675600,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533679200,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533682800,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533686400,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533690000,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533693600,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533697200,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533700800,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533704400,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533708000,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533711600,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533715200,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533718800,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533722400,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533726000,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533729600,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533733200,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533736800,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533740400,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533744000,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533747600,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533751200,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533754800,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533758400,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533762000,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533765600,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533769200,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533772800,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533776400,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533780000,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533783600,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533787200,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533790800,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533794400,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533798000,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533801600,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533805200,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533808800,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533812400,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533816000,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533819600,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533823200,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533826800,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533830400,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533834000,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533837600,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533841200,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533844800,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533848400,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533852000,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533855600,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533859200,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533862800,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533866400,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533870000,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533873600,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533877200,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533880800,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533884400,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533888000,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533891600,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533895200,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533898800,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533902400,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533906000,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533909600,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533913200,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533916800,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533920400,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533924000,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533927600,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533931200,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533934800,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533938400,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533942000,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533945600,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533949200,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533952800,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533956400,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533960000,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533963600,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533967200,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533970800,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533974400,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533978000,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533981600,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533985200,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533988800,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533992400,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533996000,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1533999600,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1534003200,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1534006800,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1534010400,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1534014000,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1534017600,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1534021200,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1534024800,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1534028400,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1534032000,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1534035600,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1534039200,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1534042800,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1534046400,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1534050000,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1534053600,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1534057200,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1534060800,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1534064400,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1534068000,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1534071600,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1534075200,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1534078800,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1534082400,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1534086000,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1534089600,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1534093200,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1534096800,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1534100400,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1534104000,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1534107600,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1534111200,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1534114800,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1534118400,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1534122000,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1534125600,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1534129200,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1534132800,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1534136400,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1534140000,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1534143600,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1534147200,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1534150800,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1534154400,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1534158000,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1534161600,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1534165200,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1534168800,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1534172400,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1534176000,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1534179600,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1534183200,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1534186800,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1534190400,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1534194000,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1534197600,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1534201200,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1534204800,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1534208400,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1534212000,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1534215600,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1534219200,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1534222800,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1534226400,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1534230000,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1534233600,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1534237200,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1534240800,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1534244400,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1534248000,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1534251600,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1534255200,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1534258800,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1534262400,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1534266000,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1534269600,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1534273200,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1534276800,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1534280400,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1534284000,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1534287600,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1534291200,
#   'close': 433.94,
#   'high': 433.94,
#   'low': 433.94,
#   'open': 433.94,
#   'volumefrom': 0,
#   'volumeto': 0},
#  {'time': 1
            
            self.info['main']['price'] = origin['close']
            self.info['main'].set_index(time_series, inplace=True)
            self.fib = None
            
    def SMA(self, window=30):

        simple = ta.SMA(self.info['main']['price'].values, timeperiod=window)
        sma_name = "SMA_{}".format(window)
        self.info['main'][sma_name] = simple
        return self
        
    def RSI(self, window=14):
        try:
            self.rsi_count += 1
        except Exception:
            self.rsi_count = 0
        rsi_simple = ta.RSI(self.info['main']['price'].values, timeperiod=window)
        rsi_name = "RSI_{}".format(window)
        self.info['main'][rsi_name] = rsi_simple
        return self
    
    def EMA(self, window=30):

        ema_simple = ta.RSI(self.info['main']['price'].values, timeperiod=window)
        ema_name = "EMA_{}".format(window)
        self.info['main'][ema_name] = ema_simple
        return self
    
    def TripleEMA(self, window=30):
        # real = TEMA(close, timeperiod=30)
        try:
            self.tema_count += 1
        except Exception:
            self.tema_count = 0
        return self
    
    def BOLL(self, dev=2, window=30):
        upper, middle, lower = ta.BBANDS(self.info['main']['price'].values, timeperiod=window, nbdevup=dev)
        boll_name = "BOLL_{0}_{1}".format(dev, window)
        self.info['main'][boll_name+"_UP"] = upper
        self.info['main'][boll_name+"_MID"] = middle
        self.info['main'][boll_name+"_LOW"] = lower
        return self
    
    def ATR(self, window=40):
        atr = ta.ATR(self.origin['high'].values, self.origin['low'].values, self.origin['close'].values,timeperiod=window)
        atr_name = "ATR_{}".format(window)
        self.info['main'][atr_name] = atr
        return self

    
    def FIBBB(self, stdev=2, window=100):
        # Get EMA
        # Get real = STDDEV(close, timeperiod=5, nbdev=1)
        dev = ta.STDDEV(self.info['main']['price'].values, timeperiod=window, nbdev=stdev)
        basis = ta.EMA(self.info['main']['price'].values, timeperiod=window)
        upper_1= basis + (0.236*dev)
        upper_2= basis + (0.382*dev)
        upper_3= basis + (0.5*dev)
        upper_4= basis + (0.618*dev)
        upper_5= basis + (0.764*dev)
        upper_6= basis + (1*dev)
        lower_1= basis - (0.236*dev)
        lower_2= basis - (0.382*dev)
        lower_3= basis - (0.5*dev)
        lower_4= basis - (0.618*dev)
        lower_5= basis - (0.764*dev)
        lower_6= basis - (1*dev)
        
        fibframe = pd.DataFrame()
        fibframe["price"] = self.origin['close']
        fibframe["up1"] = upper_1
        fibframe["up2"] = upper_2
        fibframe["up3"] = upper_3
        fibframe["up4"] = upper_4
        fibframe["up5"] = upper_5
        fibframe["up6"] = upper_6
        fibframe["basis"] = basis
        fibframe["low1"] = lower_1
        fibframe["low2"] = lower_2
        fibframe["low3"] = lower_3
        fibframe["low4"] = lower_4
        fibframe["low5"] = lower_5
        fibframe["low6"] = lower_6
        
        time_series = pd.to_datetime(self.origin['time'], unit='s')
        fibframe.set_index(time_series, inplace=True)
#         self.info["fib"].append(fibframe)
        fibframe = fibframe.dropna()
        self.fib = fibframe
        return self
    
    def __getattr__(self, name):
        if name in ('main', 'fib'):
            if name == "main":
                return self.info[name].dropna()
            else:
                return self.fib

# %%
tframe = TA(prdf)

# %%
tframe.SMA().SMA(100).RSI().RSI(window=30).BOLL().ATR().FIBBB()

# %%
tframe.main
# Out:
#                       price      SMA_30   SMA_100  RSI_14  RSI_30  \
# time
# 2018-08-07 13:00:00  433.94  433.940000  433.9400     0.0     0.0
# 2018-08-07